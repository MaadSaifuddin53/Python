# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
airport = pd.read_csv('airports.csv')
airport_freq=pd.read_csv('airport-frequencies.csv')
runway=pd.read_csv('runways.csv')

# %% [markdown]
# # Select* from Airpot

# %%
airport
# Out:
#            id    ident            type  \
# 0        6523      00A        heliport
# 1      323361     00AA   small_airport
# 2        6524     00AK   small_airport
# 3        6525     00AL   small_airport
# 4        6526     00AR          closed
# 5      322127     00AS   small_airport
# 6        6527     00AZ   small_airport
# 7        6528     00CA   small_airport
# 8      324424     00CL   small_airport
# 9      322658     00CN        heliport
# 10       6529     00CO          closed
# 11       6531     00FA   small_airport
# 12       6532     00FD        heliport
# 13       6533     00FL   small_airport
# 14       6534     00GA   small_airport
# 15       6535     00GE        heliport
# 16       6536     00HI        heliport
# 17       6537     00ID   small_airport
# 18     322581     00IG   small_airport
# 19       6538     00II        heliport
# 20       6539     00IL   small_airport
# 21       6540     00IN        heliport
# 22       6541     00IS   small_airport
# ...

# %% [markdown]
# Select* from Airpot limit3

# %%
airport.head(3)
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.949200
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.695999         450.0       NaN          US      US-AK  Anchor Point
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
# 1                no     00AA       NaN       00AA       NaN            NaN
# 2                no     00AK       NaN       00AK       NaN            NaN
#
#   keywords
# 0      NaN
# 1      NaN
# 2      NaN

# %% [markdown]
# Select id from table where id = num

# %%
airport[airport.ident=='KLAX']
# Out:
#          id ident           type                               name  \
# 27739  3632  KLAX  large_airport  Los Angeles International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 27739     33.942501    -118.407997         125.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 27739      US-CA  Los Angeles               yes     KLAX       LAX        LAX
#
#                      home_link  \
# 27739  http://www.iflylax.com/
#
#                                           wikipedia_link keywords
# 27739  http://en.wikipedia.org/wiki/Los_Angeles_Inter...      NaN

# %%
airport[airport.ident=='KLAX'][['id']]
# Out:
#          id
# 27739  3632

# %%
airport[airport.type=='large_airport'][['name']].tail()
# Out:
#                                           name
# 54793  Chengdu Shuangliu International Airport
# 54859      Ürümqi Diwopu International Airport
# 54868                          Taiping Airport
# 54882                       Zhoushuizi Airport
# 54884                          Taoxian Airport

# %% [markdown]
# Select distinct type from airport

# %%
airport.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
airport[['type']].head()
# Out:
#             type
# 0       heliport
# 1  small_airport
# 2  small_airport
# 3  small_airport
# 4         closed

# %% [markdown]
# Select ident from table where col = value and col= value

# %%
arr=airport[(airport.iso_region=='US-CA') & (airport.type=='large_airport')][['id','ident','name','iso_country']]
arr
# Out:
#          id ident                                             name iso_country
# 26109  3391  KBAB                             Beale Air Force Base          US
# 26949  3503  KEDW                           Edwards Air Force Base          US
# 27739  3632  KLAX                Los Angeles International Airport          US
# 28266  3744  KOAK       Metropolitan Oakland International Airport          US
# 28322  3752  KONT                    Ontario International Airport          US
# 29844  3862  KSAN                  San Diego International Airport          US
# 29884  3878  KSFO              San Francisco International Airport          US
# 29905  3883  KSJC  Norman Y. Mineta San Jose International Airport          US
# 29927  3892  KSMF                 Sacramento International Airport          US
# 29933  3894  KSNA         John Wayne Airport-Orange County Airport          US
# 29982  3908  KSUU                            Travis Air Force Base          US
# ...

# %%
airport[(airport.iso_region == 'US-CA') & (airport.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#       ident                                             name   municipality
# 26109  KBAB                             Beale Air Force Base     Marysville
# 26949  KEDW                           Edwards Air Force Base        Edwards
# 27739  KLAX                Los Angeles International Airport    Los Angeles
# 28266  KOAK       Metropolitan Oakland International Airport        Oakland
# 28322  KONT                    Ontario International Airport        Ontario
# 29844  KSAN                  San Diego International Airport      San Diego
# 29884  KSFO              San Francisco International Airport  San Francisco
# 29905  KSJC  Norman Y. Mineta San Jose International Airport       San Jose
# 29927  KSMF                 Sacramento International Airport     Sacramento
# 29933  KSNA         John Wayne Airport-Orange County Airport      Santa Ana
# 29982  KSUU                            Travis Air Force Base      Fairfield
# ...

# %%
airport.head(1)
# Out:
#      id ident      type               name  latitude_deg  longitude_deg  \
# 0  6523   00A  heliport  Total Rf Heliport     40.070801     -74.933601
#
#    elevation_ft continent iso_country iso_region municipality  \
# 0          11.0       NaN          US      US-PA     Bensalem
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
#
#   keywords
# 0      NaN

# %%
airport[(airport.type=='helliport') & (airport.iso_region=='US')]#[['id','ident','iso_region']]
# Out:
# Empty DataFrame
# Columns: [id, ident, type, name, latitude_deg, longitude_deg, elevation_ft, continent, iso_country, iso_region, municipality, scheduled_service, gps_code, iata_code, local_code, home_link, wikipedia_link, keywords]
# Index: []

# %%
airport[(airport.iso_region == 'US-CA') & (airport.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#       ident                                             name   municipality
# 26109  KBAB                             Beale Air Force Base     Marysville
# 26949  KEDW                           Edwards Air Force Base        Edwards
# 27739  KLAX                Los Angeles International Airport    Los Angeles
# 28266  KOAK       Metropolitan Oakland International Airport        Oakland
# 28322  KONT                    Ontario International Airport        Ontario
# 29844  KSAN                  San Diego International Airport      San Diego
# 29884  KSFO              San Francisco International Airport  San Francisco
# 29905  KSJC  Norman Y. Mineta San Jose International Airport       San Jose
# 29927  KSMF                 Sacramento International Airport     Sacramento
# 29933  KSNA         John Wayne Airport-Orange County Airport      Santa Ana
# 29982  KSUU                            Travis Air Force Base      Fairfield
# ...

# %%
airport.columns
# Out:
# [Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#         'elevation_ft', 'continent', 'iso_country', 'iso_region',
#         'municipality', 'scheduled_service', 'gps_code', 'iata_code',
#         'local_code', 'home_link', 'wikipedia_link', 'keywords'],
#        dtype='object')]

# %%
airport.values
# Out:
# array([[6523, '00A', 'heliport', ..., nan, nan, nan],
#        [323361, '00AA', 'small_airport', ..., nan, nan, nan],
#        [6524, '00AK', 'small_airport', ..., nan, nan, nan],
#        ...,
#        [46378, 'ZZ-0001', 'heliport', ..., 'http://www.sealandgov.org/',
#         'http://en.wikipedia.org/wiki/Principality_of_Sealand',
#         'Roughs Tower Helipad'],
#        [307326, 'ZZ-0002', 'small_airport', ..., nan, nan, nan],
#        [313629, 'ZZZZ', 'small_airport', ..., nan,
#         'http://wikimapia.org/6705190/Satsuma-Iwo-jima-Airport',
#         'SATSUMA,IWOJIMA,RJX7']], dtype=object)

# %%
airport_freq
# Out:
#            id  airport_ref airport_ident   type          description  \
# 0       70518         6528          00CA   CTAF                 CTAF
# 1      307581         6589          01FL  ARCAL                  NaN
# 2       75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3       60191         6756          04CA   CTAF                 CTAF
# 4       59287         6779          04MS   UNIC               UNICOM
# 5       60682         6784          04NV   UNIC               UNICOM
# 6       60091         6812          05CL   CTAF                 CTAF
# 7       63835         6853          05UT   UNIC               UNICOM
# 8       70676         6868          06FA    APP       PALM BEACH APP
# 9       70677         6868          06FA    GND                  GND
# 10      70678         6868          06FA    TWR                  TWR
# 11      65868         6887          06MO   CTAF                 CTAF
# 12      71176         6924          07FA   UNIC               UNICOM
# ...

# %%
airport_freq.head(5)
# Out:
#        id  airport_ref airport_ident   type          description  \
# 0   70518         6528          00CA   CTAF                 CTAF
# 1  307581         6589          01FL  ARCAL                  NaN
# 2   75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3   60191         6756          04CA   CTAF                 CTAF
# 4   59287         6779          04MS   UNIC               UNICOM
#
#    frequency_mhz
# 0          122.9
# 1          122.9
# 2          122.8
# 3          122.9
# 4          122.8

# %%
airport_freq[airport_freq.airport_ident=='06FA'].sort_values('type',ascending=False)
# Out:
#        id  airport_ref airport_ident type     description  frequency_mhz
# 10  70678         6868          06FA  TWR             TWR         120.40
# 9   70677         6868          06FA  GND             GND         121.65
# 8   70676         6868          06FA  APP  PALM BEACH APP         124.60

# %%
airport_freq[airport_freq.airport_ident=='06FA'].sort_values('type')
# Out:
#        id  airport_ref airport_ident type     description  frequency_mhz
# 8   70676         6868          06FA  APP  PALM BEACH APP         124.60
# 9   70677         6868          06FA  GND             GND         121.65
# 10  70678         6868          06FA  TWR             TWR         120.40

# %% [markdown]
# Select* from table wheren col in(value)

# %%
airport[airport.type.isin(['heliport','ballonport'])].tail()
# Out:
#            id    ident      type                       name  latitude_deg  \
# 54513  312611  ZA-0117  heliport              Pumba Helipad    -33.387799
# 54515  312624  ZA-0119  heliport         Cape Town Heliport    -33.901018
# 54536  318475  ZA-0140  heliport  Kuruman Hospital Heliport    -27.459904
# 54628  301278      ZIZ  heliport           Zamzama Heliport     26.710944
# 54888   46378  ZZ-0001  heliport            Sealand Helipad     51.894444
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 54513      26.410595           NaN        AF          ZA      ZA-EC
# 54515      18.425936           NaN        AF          ZA      ZA-WC
# 54536      23.443762           NaN        AF          ZA      ZA-NC
# 54628      67.667250         128.0        AS          PK      PK-SD
# 54888       1.482500          40.0        EU          GB     GB-ENG
#
#              municipality scheduled_service gps_code iata_code local_code  \
# ...

# %% [markdown]
# select iso_country, type, count(*) from airports group by iso_country, type order by iso_country, type

# %%
airport.groupby(['iso_country','type']).count()
# Out:
#                              id  ident  name  latitude_deg  longitude_deg  \
# iso_country type
# AD          heliport          2      2     2             2              2
# AE          closed            4      4     4             4              4
#             heliport         21     21    21            21             21
#             large_airport     4      4     4             4              4
#             medium_airport    8      8     8             8              8
#             seaplane_base     3      3     3             3              3
#             small_airport    16     16    16            16             16
# AF          closed            2      2     2             2              2
#             heliport          3      3     3             3              3
#             medium_airport    8      8     8             8              8
#             small_airport    51     51    51            51             51
# ...

# %%
arr=airport.groupby(['iso_region','type']).count().tail(2)
arr
# Out:
#                           id  ident  name  latitude_deg  longitude_deg  \
# iso_region type
# ZW-U-A     small_airport   5      5     5             5              5
# ZZ-U-A     closed          7      7     7             7              7
#
#                           elevation_ft  continent  iso_country  municipality  \
# iso_region type
# ZW-U-A     small_airport             5          5            5             1
# ZZ-U-A     closed                    0          7            7             0
#
#                           scheduled_service  gps_code  iata_code  local_code  \
# iso_region type
# ZW-U-A     small_airport                  5         3          0           0
# ZZ-U-A     closed                         7         1          0           0
#
#                           home_link  wikipedia_link  keywords
# iso_region type
# ZW-U-A     small_airport          0               0         1
# ZZ-U-A     closed                 0               0         0

# %%
arr2=pd.DataFrame(arr)
arr2
# Out:
#                             0
# iso_region type
# AD-04      heliport         1
# AD-07      heliport         1
# AE-AZ      closed           1
#            heliport        11
#            large_airport    1
#            medium_airport   4
#            seaplane_base    1
#            small_airport   12
# AE-DU      closed           1
#            heliport         8
#            large_airport    2
#            medium_airport   2
#            seaplane_base    2
#            small_airport    2
# AE-FU      medium_airport   1
# AE-RK      medium_airport   1
#            small_airport    1
# AE-SH      large_airport    1
# AE-U-A     closed           2
#            heliport         1
# AE-UQ      heliport         1
#            small_airport    1
# AF-BAL     medium_airport   1
#            small_airport    1
# AF-BAM     small_airport    4
# AF-BDG     small_airport    1
# AF-BDS     small_airport    7
# AF-FRA     small_airport    3
# AF-FYB     medium_airport   1
# ...

# %% [markdown]
# select iso_country, type, count(*) from airports group by iso_country, type order by iso_country, count(*) desc

# %%
airport.groupby(['iso_country','type']).size().to_frame('size').reset_index().sort_values(['iso_country','size'],ascending=[True,False])
# Out:
#     iso_country            type  size
# 0            AD        heliport     2
# 2            AE        heliport    21
# 6            AE   small_airport    16
# 4            AE  medium_airport     8
# 1            AE          closed     4
# 3            AE   large_airport     4
# 5            AE   seaplane_base     3
# 10           AF   small_airport    51
# 9            AF  medium_airport     8
# 8            AF        heliport     3
# 7            AF          closed     2
# 12           AG   small_airport     2
# 11           AG  medium_airport     1
# 13           AI  medium_airport     1
# 14           AL          closed     4
# 17           AL  medium_airport     3
# 15           AL        heliport     2
# 18           AL   small_airport     2
# 16           AL   large_airport     1
# 22           AM   small_airport     5
# 19           AM          closed     4
# 21           AM  medium_airport     3
# 20           AM   large_airport     1
# 26           AO   small_airport    73
# ...

# %%
airport.tail(5)
# Out:
#            id    ident            type                       name  \
# 54886  317861     ZYYK  medium_airport      Yingkou Lanqi Airport
# 54887   32753     ZYYY  medium_airport    Shenyang Dongta Airport
# 54888   46378  ZZ-0001        heliport            Sealand Helipad
# 54889  307326  ZZ-0002   small_airport  Glorioso Islands Airstrip
# 54890  313629     ZZZZ   small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 54886     40.542524     122.358600           0.0        AS          CN
# 54887     41.784401     123.496002           NaN        AS          CN
# 54888     51.894444       1.482500          40.0        EU          GB
# 54889    -11.584278      47.296389          11.0        AF          TF
# 54890     30.784722     130.270556         338.0        AS          JP
#
#       iso_region      municipality scheduled_service gps_code iata_code  \
# ...

# %%
airport.count()
# Out:
# id                   54891
# ident                54891
# type                 54891
# name                 54891
# latitude_deg         54891
# longitude_deg        54891
# elevation_ft         47915
# continent            27307
# iso_country          54644
# iso_region           54891
# municipality         49258
# scheduled_service    54891
# gps_code             41019
# iata_code             9172
# local_code           28588
# home_link             2957
# wikipedia_link        9822
# keywords              9121
# dtype: int64

# %%
airport['id'].count()
# Out:
# 54891

# %% [markdown]
# select type, count(*) from airports where iso_country = 'US' group by type having count(*) > 1000 order by count(*) desc

# %%
data=pd.DataFrame(airport)

# %%
data.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'iso_country', 'iso_region',
#        'municipality', 'scheduled_service', 'gps_code', 'iata_code',
#        'local_code', 'home_link', 'wikipedia_link', 'keywords'],
#       dtype='object')

# %%
data.tail()
# Out:
#            id    ident            type                       name  \
# 54886  317861     ZYYK  medium_airport      Yingkou Lanqi Airport
# 54887   32753     ZYYY  medium_airport    Shenyang Dongta Airport
# 54888   46378  ZZ-0001        heliport            Sealand Helipad
# 54889  307326  ZZ-0002   small_airport  Glorioso Islands Airstrip
# 54890  313629     ZZZZ   small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 54886     40.542524     122.358600           0.0        AS          CN
# 54887     41.784401     123.496002           NaN        AS          CN
# 54888     51.894444       1.482500          40.0        EU          GB
# 54889    -11.584278      47.296389          11.0        AF          TF
# 54890     30.784722     130.270556         338.0        AS          JP
#
#       iso_region      municipality scheduled_service gps_code iata_code  \
# ...

# %% [markdown]
# select type, count() from airports where iso_country = 'US' group by type having count() > 1000 order by count(*) desc

# %%
data[data.iso_country=='US'].groupby(type).filter(lambda x:len(x)>1000).groupby('type').size().sort_values(ascending=False)
# Out:
# type
# small_airport     13725
# heliport           6247
# closed             1287
# medium_airport      692
# seaplane_base       564
# large_airport       170
# balloonport          18
# dtype: int64

# %%
airport[airport.iso_country == 'US'].groupby('type').filter(lambda g: len(g) > 1000).groupby('type').size().sort_values(ascending=False)
# Out:
# type
# small_airport    13725
# heliport          6247
# closed            1287
# dtype: int64

# %%
data.sort_values(by='type')
# Out:
#            id    ident           type  \
# 49805  328796  US-0934    balloonport
# 15472   16882     CO28    balloonport
# 6375    12432     5KS0    balloonport
# 25051   18292     JY33    balloonport
# 25022   18263     JY03    balloonport
# 1329     7767     12JY    balloonport
# 1398     7829      13M    balloonport
# 17246  323838  DE-0351    balloonport
# 12078  324445  BE-0012    balloonport
# 5985    12057     55NJ    balloonport
# 36691   45548     NY80    balloonport
# 32596   21769     MA26    balloonport
# 5535    11644     4OH6    balloonport
# 10881   38811  AR-0136    balloonport
# 3904    10140     35JY    balloonport
# 30475  314582      KZR    balloonport
# 25059   18299     JY42    balloonport
# 50481   25392     VA60    balloonport
# 39322   24352     RI16    balloonport
# 3185    45530     2JY7    balloonport
# 2881     9213     28NC    balloonport
# 6143    46296     59ID    balloonport
# 21159  322152  FR-0354    balloonport
# ...

# %%
data.nlargest(10,columns='id').tail(10)
# Out:
#            id    ident           type  \
# 35090  330066  MX-0937       heliport
# 35089  330065  MX-0936       heliport
# 11492  330063     AT25  small_airport
# 35881  330057  NG-0008         closed
# 35880  330056  NG-0007  small_airport
# 49932  330045  US-1060       heliport
# 38601  330040  PH-0167  large_airport
# 35879  330039  NG-0006  large_airport
# 49931  330020  US-1059         closed
# 49930  330013  US-1058         closed
#
#                                            name  latitude_deg  longitude_deg  \
# 35090                           Helimaz Chiapas     14.772546     -92.382491
# 35089                       Los Leones Heliport     28.739082    -105.981582
# 11492                      Showa Station Skiway    -69.006167      39.590000
# 35881                           Suntai Airstrip      7.909458      10.374472
# 35880                           Lokoja Airstrip      7.801829       6.582793
# ...

# %% [markdown]
# # select max(length_ft), min(length_ft), mean(length_ft), median(length_ft) from runways

# %%
df=data.agg({'latitude_deg':['mean','min','max','median']})
df
# Out:
#         latitude_deg
# mean       25.682481
# min       -90.000000
# max        89.500000
# median     36.499699

# %%
df.T
# Out:
#                    mean   min   max     median
# latitude_deg  25.682481 -90.0  89.5  36.499699

# %%
data.groupby('type').count()
# Out:
#                    id  ident   name  latitude_deg  longitude_deg  \
# type
# balloonport        23     23     23            23             23
# closed           3514   3514   3514          3514           3514
# heliport        11228  11228  11228         11228          11228
# large_airport     623    623    623           623            623
# medium_airport   4550   4550   4550          4550           4550
# seaplane_base    1014   1014   1014          1014           1014
# small_airport   33939  33939  33939         33939          33939
#
#                 elevation_ft  continent  iso_country  iso_region  \
# type
# balloonport               21          5           23          23
# closed                  2533       1488         3510        3514
# heliport                9492       4247        11228       11228
# large_airport            600        416          622         623
# medium_airport          4342       3303         4539        4550
# ...

# %%
data.head(1)
# Out:
#      id ident      type               name  latitude_deg  longitude_deg  \
# 0  6523   00A  heliport  Total Rf Heliport     40.070801     -74.933601
#
#    elevation_ft continent iso_country iso_region municipality  \
# 0          11.0       NaN          US      US-PA     Bensalem
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
#
#   keywords
# 0      NaN

# %%
data.groupby('ident').count()
# Out:
#        id  type  name  latitude_deg  longitude_deg  elevation_ft  continent  \
# ident
# 00A     1     1     1             1              1             1          0
# 00AA    1     1     1             1              1             1          0
# 00AK    1     1     1             1              1             1          0
# 00AL    1     1     1             1              1             1          0
# 00AR    1     1     1             1              1             1          0
# 00AS    1     1     1             1              1             1          0
# 00AZ    1     1     1             1              1             1          0
# 00CA    1     1     1             1              1             1          0
# 00CL    1     1     1             1              1             1          0
# 00CN    1     1     1             1              1             1          0
# 00CO    1     1     1             1              1             1          0
# ...

# %%
data[['id','iso_country','iso_region','type']][data.iso_country=='US'][data.type=='closed']
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            id iso_country iso_region    type
# 4        6526          US      US-AR  closed
# 10       6529          US      US-CO  closed
# 32       6550          US      US-MT  closed
# 44       6559          US      US-PA  closed
# 51       6566          US      US-TX  closed
# 52       6567          US      US-UT  closed
# 67       6581          US      US-MI  closed
# 106      6618          US      US-OK  closed
# 107      6619          US      US-OR  closed
# 115      6627          US      US-TX  closed
# 129     43030          US      US-AR  closed
# 130      6640          US      US-AZ  closed
# 180      6687          US      US-TX  closed
# 197      6703          US      US-FL  closed
# 200      6705          US      US-OH  closed
# 217      6722          US      US-MO  closed
# ...

# %%
airport.iloc[[1,3,4,5]].iso_region
# Out:
# 1    US-KS
# 3    US-AL
# 4    US-AR
# 5    US-OK
# Name: iso_region, dtype: object

# %%
df1=airport.iloc[:10,:1]
df1
# Out:
#        id
# 0    6523
# 1  323361
# 2    6524
# 3    6525
# 4    6526
# 5  322127
# 6    6527
# 7    6528
# 8  324424
# 9  322658

# %%
del airport['type']

# %%
airport.iloc[0:3,:]=np.nan
airport.head()
# Out:
#        id ident                                name  latitude_deg  \
# 0     NaN   NaN                                 NaN           NaN
# 1     NaN   NaN                                 NaN           NaN
# 2     NaN   NaN                                 NaN           NaN
# 3  6525.0  00AL                        Epps Airpark     34.864799
# 4  6526.0  00AR  Newport Hospital & Clinic Heliport     35.608700
#
#    longitude_deg  elevation_ft continent iso_country iso_region municipality  \
# 0            NaN           NaN       NaN         NaN        NaN          NaN
# 1            NaN           NaN       NaN         NaN        NaN          NaN
# 2            NaN           NaN       NaN         NaN        NaN          NaN
# 3     -86.770302         820.0       NaN          US      US-AL      Harvest
# 4     -91.254898         237.0       NaN          US      US-AR      Newport
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# ...

# %%
df1=data.dropna(how='all')
df1.head()
# Out:
#          id ident                                name  latitude_deg  \
# 3    6525.0  00AL                        Epps Airpark     34.864799
# 4    6526.0  00AR  Newport Hospital & Clinic Heliport     35.608700
# 5  322127.0  00AS                      Fulton Airport     34.942803
# 6    6527.0  00AZ                      Cordes Airport     34.305599
# 7    6528.0  00CA             Goldstone /Gts/ Airport     35.350498
#
#    longitude_deg  elevation_ft continent iso_country iso_region municipality  \
# 3     -86.770302         820.0       NaN          US      US-AL      Harvest
# 4     -91.254898         237.0       NaN          US      US-AR      Newport
# 5     -97.818019        1100.0       NaN          US      US-OK         Alex
# 6    -112.165001        3810.0       NaN          US      US-AZ       Cordes
# 7    -116.888000        3038.0       NaN          US      US-CA      Barstow
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# ...
