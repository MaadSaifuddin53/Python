# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
data=pd.read_csv('ted.csv')

# %%
data.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2550, step=1)

# %%
data.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
data.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views'],
#       dtype='object')

# %%
data.shape
# Out:
# (2550, 17)

# %%
data.ndim
# Out:
# 2

# %%
data.duration.value_counts(dropna=False).sort_index().tail()
# Out:
# 3573    1
# 3608    1
# 3955    1
# 4587    1
# 5256    1
# Name: duration, dtype: int64

# %%
data.dropna('columns',how='all').shape
# Out:
# (2550, 17)

# %% [markdown]
# # loc is for selecting things bys labels

# %%
data.loc[0,:]
# Out:
# comments                                                           4553
# description           Sir Ken Robinson makes an entertaining and pro...
# duration                                                           1164
# event                                                           TED2006
# film_date                                                    1140825600
# languages                                                            60
# main_speaker                                               Ken Robinson
# name                          Ken Robinson: Do schools kill creativity?
# num_speaker                                                           1
# published_date                                               1151367060
# ratings               [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# related_talks         [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# speaker_occupation                                      Author/educator
# ...

# %%
data.loc[0:2,:]
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# ...

# %%
data.loc[:,['event','film_date']].tail(3)
# Out:
#              event   film_date
# 2547       TED2017  1492992000
# 2548  TEDxMileHigh  1499472000
# 2549       TED2017  1492992000

# %%
data.loc[:,'event':'name']
# Out:
#                event   film_date  languages  \
# 0            TED2006  1140825600         60
# 1            TED2006  1140825600         43
# 2            TED2006  1140739200         26
# 3            TED2006  1140912000         35
# 4            TED2006  1140566400         48
# 5            TED2006  1138838400         36
# 6            TED2006  1140739200         31
# 7            TED2006  1140652800         19
# 8            TED2006  1138838400         32
# 9            TED2006  1140825600         31
# 10           TED2006  1140912000         27
# 11           TED2006  1140912000         20
# 12           TED2006  1140652800         24
# 13           TED2006  1139184000         27
# 14           TED2006  1140652800         25
# 15           TED2006  1140652800         31
# 16           TED2004  1077753600         32
# 17           TED2006  1140739200         27
# 18           TED2005  1109289600         22
# 19    TEDGlobal 2005  1121299200         32
# ...

# %%
data[data.film_date==1140825600].event
# Out:
# 0    TED2006
# 1    TED2006
# 9    TED2006
# Name: event, dtype: object

# %%
data.loc[data.film_date==1140825600,'event']
# Out:
# 0    TED2006
# 1    TED2006
# 9    TED2006
# Name: event, dtype: object

# %% [markdown]
# # use of iloc

# %%
data.iloc[0:3,0:2]
# Out:
#    comments                                        description
# 0      4553  Sir Ken Robinson makes an entertaining and pro...
# 1       265  With the same humor and humanity he exuded in ...
# 2       124  New York Times columnist David Pogue takes aim...

# %%
data.iloc[0:2,0:8]
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name
# 0  Ken Robinson: Do schools kill creativity?
# 1       Al Gore: Averting the climate crisis

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry',index_col='country')
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.ix['Albania':'Andorra',0:3]
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#          beer_servings  spirit_servings  wine_servings
# country
# Albania             89              132             54
# Algeria             25                0             14
# Andorra            245              138            312

# %%
drinks.ix['Albania',0]
# Out:
# C:\Users\Maad_Saifuddin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 89

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64
